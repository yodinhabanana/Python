# %% [markdown]
# # Aprendizagem por regras

# %% [markdown]
# ### Oner e PRISM

# %%
## Algoritmo ONER => Testar coisas simples primeiro
## um atributo faz todo o trabalho
## não utiliza outro atributo

# %%
## Algoritmo PRISM =>

# %%
import Orange
