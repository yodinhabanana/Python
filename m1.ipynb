# %% [markdown]
# ## Importando as bibliotecas básicas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Base de dados de crédito

# %%
import opendatasets as od # importação da base de dados (credit-risk-dataset)
url = "https://www.kaggle.com/datasets/laotse/credit-risk-dataset"
od.download(url)
# Out:
# Skipping, found downloaded files in "./credit-risk-dataset" (use force=True to force download)

# %%
df = pd.read_csv("credit-risk-dataset/credit_risk_dataset.csv")
df.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# ...

# %%
df.info() # informacao do meu data frame
df.tail(10) # ultimos 10
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB
# ...

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
df[df['person_income'] >= 69995.685578]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 6              26          77100                  RENT                8.0
# 7              24          78956                  RENT                5.0
# 8              24          83000                  RENT                8.0
# 10             22          85000                  RENT                6.0
# 12             23          95000                  RENT                2.0
# ...           ...            ...                   ...                ...
# 32570          58          72000                  RENT                5.0
# 32573          56          90000              MORTGAGE                0.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
sns.countplot(x="person_age", data=df[df["person_age"] >= 60])
# Out:
# <Axes: xlabel='person_age', ylabel='count'>

# %%
df["person_age"].describe() #descreve
# Out:
# count    32581.000000
# mean        27.734600
# std          6.348078
# min         20.000000
# 25%         23.000000
# 50%         26.000000
# 75%         30.000000
# max        144.000000
# Name: person_age, dtype: float64

# %%
df[df["person_age"] > 100] # idade absurda gente q isso
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 32297         144        6000000              MORTGAGE               12.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 81        VENTURE          C       4800          13.57            0
# 183     EDUCATION          B       6000          11.86            0
# 575     EDUCATION          B      20400          10.25            0
# 747       VENTURE          B      20000            NaN            0
# 32297    PERSONAL          C       5000          12.73            0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# ...

# %%
plt.hist(x = df['person_income'])
# Out:
# (array([3.2542e+04, 3.3000e+01, 3.0000e+00, 2.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([4.0000e+03, 6.0360e+05, 1.2032e+06, 1.8028e+06, 2.4024e+06,
#         3.0020e+06, 3.6016e+06, 4.2012e+06, 4.8008e+06, 5.4004e+06,
#         6.0000e+06]),
#  <BarContainer object of 10 artists>)

# %%
df['person_income'].describe()
# Out:
# count    3.258100e+04
# mean     6.607485e+04
# std      6.198312e+04
# min      4.000000e+03
# 25%      3.850000e+04
# 50%      5.500000e+04
# 75%      7.920000e+04
# max      6.000000e+06
# Name: person_income, dtype: float64

# %%
df = df[df["person_age"] < 100]

# %%
df['person_income'].describe()
# Out:
# count    3.257600e+04
# mean     6.588214e+04
# std      5.253499e+04
# min      4.000000e+03
# 25%      3.850000e+04
# 50%      5.500000e+04
# 75%      7.920000e+04
# max      2.039784e+06
# Name: person_income, dtype: float64

# %%
plt.hist(df[df["person_income"] < 200000]["person_income"], bins=50)
plt.show() # mostra rendas ate 200 mil

# %%
outliers = df[df["person_income"] >= 200000] # outliers (renda maior que 200000)
print(outliers)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15             23         500000              MORTGAGE                7.0
# 33             25         306000                  RENT                2.0
# 34             26         300000              MORTGAGE               10.0
# 42             26         300000              MORTGAGE               10.0
# 43             23         300000                   OWN                1.0
# ...           ...            ...                   ...                ...
# 32542          67         200000              MORTGAGE                2.0
# 32543          52         720000              MORTGAGE                1.0
# 32544          58         780000              MORTGAGE                7.0
# 32546          60        1900000              MORTGAGE                5.0
# 32551          58         780000              MORTGAGE                7.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
plt.hist(x = df['person_age']);

# %%
grafico = px.scatter_matrix(df, dimensions=['person_age', 'person_income', 'loan_grade'], color = 'cb_person_default_on_file')
grafico.show()

# %% [markdown]
# # Tratamento de valores inconsistentes/faltantes

# %%
df = df[df['person_age'] > 0] # retira quem tem idade abaixo de 0 
df = df[df['person_income'] > 0] # retira quem tem income negativo

# %%
print(df['person_age'].mean()) # imprime a media de idade
print(df['person_income'].mean()) # imprime a media de income
# Out:
# 27.718043958742633
# 65882.14126964637

# %%
df.isnull() # verifica se falta algo ( nao falta nada )
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 0           False          False                  False              False
# 1           False          False                  False              False
# 2           False          False                  False              False
# 3           False          False                  False              False
# 4           False          False                  False              False
# ...           ...            ...                    ...                ...
# 32576       False          False                  False              False
# 32577       False          False                  False              False
# 32578       False          False                  False              False
# 32579       False          False                  False              False
# 32580       False          False                  False              False
#
# ...
